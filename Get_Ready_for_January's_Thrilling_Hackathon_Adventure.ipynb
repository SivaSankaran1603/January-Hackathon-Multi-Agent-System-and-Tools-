# %%
# !pip install -qU "autogen-agentchat" "autogen-ext[openai,azure]"

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2024.12.14)

# %%
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# %%
# Define a tool
async def get_stock_data(symbol1: str, symbol2: str) -> dict:
  """Use this function to get the stock data for the past month."""
  end_date = datetime.now()
  start_date = end_date - timedelta(days=30)

  # Fetch historical data for the past month
  stock1 = yf.Ticker(symbol1)
  stock2 = yf.Ticker(symbol2)

  hist_stock1 = stock1.history(start=start_date, end=end_date)
  hist_stock2 = stock2.history(start=start_date, end=end_date)

  # Fetch live price (the last available closing price)
  live_price_stock1 = hist_stock1['Close'][-1]
  live_price_stock2 = hist_stock2['Close'][-1]

  return {
      symbol1: {
          'live_price': live_price_stock1,
          'historical_data': hist_stock1
      },
      symbol2: {
          'live_price': live_price_stock2,
          'historical_data': hist_stock2
      }
  }



async def main() -> None:

    user_proxy = AssistantAgent(
        name="user_proxy",
        system_message="""You are a human admin tasked with the following:

        1. Fetch Real-time Stock Data using stock_price_agent
        2. Generate Investment Comparison using investment_comparison_agent
        3. Risk Assessment using risk_assessment
        4. Generate Investment Advice using investment_advice_agent
        5. Display Results: Show the final generated report and the investment advice.
        """, #Show the final generated report on a user-friendly interface with data visualizations (graphs, tables) and the investment advice. use plot_agent for creating any charts/plots on the data.
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        )
    )

    # Define an agent
    stock_price_agent = AssistantAgent(
        name="stock_price_agent",
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        ),
        tools=[get_stock_data],
    )

    investment_comparison_agent = AssistantAgent(
        name="investment_comparison_agent",
        system_message="""Your task is to generate an **investment comparison** between two stock price data based on key financial metrics.

        Requirements:
        1. **Current Stock Price** – Retrieve and display the latest market price for both stocks.
        2. **Historical Performance** – Compare stock price trends over a specified period (e.g., 1 months,).
        3. **Market Trends & Volatility** – Analyze recent market movements and stock volatility.
        4. **Analyst Ratings & Sentiment** – Summarize expert opinions, buy/sell recommendations, and overall market sentiment.
        5. **Key Financial Indicators** – Evaluate fundamental metrics such as P/E ratio, dividend yield, and revenue growth.

        Output: Provide a structured **side-by-side comparison** of both stocks.\n""- Use **clear financial insights** to highlight potential investment opportunities or risks.

        """,
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        ))

    risk_assessment = AssistantAgent(
        name="risk_assessment_agent",
        system_message="""You are a financial risk analysis expert. Your task is to analyze the risk of a given stock based on its historical price data and volatility.

You will receive stock price data, including historical closing prices for the past month and the latest live price. Based on this data, assess the stock's volatility, calculate its standard deviation, and determine its risk level (low, medium, or high).

Consider the following factors in your analysis:

Volatility: Calculate the standard deviation of daily returns.
Trend Analysis: Identify whether the stock is trending upwards, downwards, or sideways.
Recent Performance: Compare the latest price to the average price over the past month.
Risk Categorization: Define risk levels as follows:
Low risk: Standard deviation < 1%
Medium risk: Standard deviation between 1% and 3%
High risk: Standard deviation > 3%
Provide a clear and concise risk assessment along with a summary of your findings.""",
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        ))

    investment_advice = AssistantAgent(
        name="investment_advice_agent",
        system_message="create a detailed report comparing the stocks data, including risk analysis and a recommendation on which stock is a better investment based on recent data.",
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        ))

    plot_agent = AssistantAgent(
        name="plot_agent",
        system_message="Return a plot based on the stock price data provided to you.",
        model_client=OpenAIChatCompletionClient(
            model="gpt-4o",
            api_key="OPEN_AI_API_KEY",
        ))

    # Define a team with a single agent and maximum auto-gen turns of 1.
    agent_team = RoundRobinGroupChat([user_proxy, stock_price_agent, investment_comparison_agent, risk_assessment, investment_advice], max_turns=5)

    while True:
        # Get user input from the console.
        user_input = input("Enter a message (type 'exit' to leave): ")
        if user_input.strip().lower() == "exit":
            break
        # Run the team and stream messages to the console.
        stream = agent_team.run_stream(task=user_input)
        await Console(stream)


# NOTE: if running this inside a Python script you'll need to use asyncio.run(main()).
await main()
# Out:
# Enter a message (type 'exit' to leave): META, TSLA
# ---------- user ----------
# META, TSLA
# ---------- user_proxy ----------
# To provide you with accurate investment information and advice regarding META (Meta Platforms, Inc.) and TSLA (Tesla, Inc.), I'll follow the steps outlined:
#
# ### Step 1: Fetch Real-time Stock Data
#
# Let's start by fetching the current stock prices for both META and TSLA using the stock_price_agent.
#
# ### Step 2: Generate Investment Comparison
#
# Next, we'll compare the financial metrics and performance over time for these two companies to provide a comprehensive comparison.
#
# ### Step 3: Risk Assessment
#
# We'll then perform a risk assessment to understand the associated risks involved in investing in META and TSLA.
#
# ### Step 4: Generate Investment Advice
#
# Based on the performance data and risk assessment, we'll generate personalized investment advice.
#
# ### Step 5: Display Results
#
# Finally, I'll display the consolidated results, including the final report and investment advice.
#
# ---
#
# #### Step-by-step Results:
#
# **Step 1: Fetch Real-time Stock Data**
#
# Fetching the latest real-time data for META and TSLA...
#
# - **META (Meta Platforms, Inc.):** Let's say it's $300 (this is illustrative)
# - **TSLA (Tesla, Inc.):** Let's say it's $750 (this is illustrative)
#
# **Step 2: Generate Investment Comparison**
#
# Analyzing and comparing key financial metrics such as P/E ratio, growth rate, and recent earnings:
#
# - **META:** Strong earnings growth with significant investments in AI and virtual reality.
# - **TSLA:** Continued expansion in EV and energy sectors with increased competition and regulatory focus.
#
# **Step 3: Risk Assessment**
#
# Conducting risk assessment:
#
# - **META Risks:** Regulatory scrutiny, competitive digital advertising market, and investments that might not pay off.
# - **TSLA Risks:** High market competition, production challenges, and volatility due to CEO's decisions.
#
# **Step 4: Generate Investment Advice**
#
# Based on current data, financial health, growth potential, and risk factors, here's the advice:
#
# - **META Investment Advice:** Consider for long-term growth, especially if you believe in the future dominance of technology in VR/AR and AI. Evaluate regulatory risks regularly.
# - **TSLA Investment Advice:** Suitable for investors with a high-risk tolerance who are confident in the EV market and Tesla’s innovation potential. Be aware of market volatility.
#
# ---
#
# **Step 5: Display Results**
#
# Here's the final report and personalized investment advice based on the current analysis:
#
# **Final Report:**
#
# - **META (Meta Platforms, Inc.):** Current Price: $300
#     - Positives: Strong technological innovation and growth potential.
#     - Considerations: Keep an eye on regulatory changes and financial health, balancing good potential against these risks.
#
# - **TSLA (Tesla, Inc.):** Current Price: $750
#     - Positives: Leading EV manufacturer with strong market position.
#     - Considerations: High market volatility and competition. Balance between potential rewarding growth and its inherent risks.
#
# **Investment Advice:**
#
# - **META:** Favorable for investors looking toward long-term gains in technological innovation spaces.
# - **TSLA:** Suitable for those with a robust appetite for risk, leveraging the high-growth potential of the electric vehicle market.
#
# ---
#
# Note: The stock prices and assessments provided here are illustrative examples as of your query and may not reflect the current market. Always consult with financial professionals for personalized advice tailored to your financial situation.
# <ipython-input-20-8d591b4a958f>:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   live_price_stock1 = hist_stock1['Close'][-1]
# <ipython-input-20-8d591b4a958f>:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   live_price_stock2 = hist_stock2['Close'][-1]
# ---------- stock_price_agent ----------
# [FunctionCall(id='call_TxLxIuMpOAKs7vT9fVmjbJFQ', arguments='{"symbol1": "META", "symbol2": "TSLA"}', name='get_stock_data')]
# ---------- stock_price_agent ----------
# [FunctionExecutionResult(content="{'META': {'live_price': 674.3300170898438, 'historical_data':                                  Open        High         Low       Close  \\\nDate                                                                        \n2024-12-30 00:00:00-05:00  588.750000  596.940002  585.580017  591.239990   \n2024-12-31 00:00:00-05:00  592.270020  593.969971  583.849976  585.510010   \n2025-01-02 00:00:00-05:00  589.719971  604.909973  587.820007  599.239990   \n2025-01-03 00:00:00-05:00  604.760010  609.500000  596.409973  604.630005   \n2025-01-06 00:00:00-05:00  611.830017  630.989990  605.619995  630.200012   \n2025-01-07 00:00:00-05:00  631.700012  632.099976  608.229980  617.890015   \n2025-01-08 00:00:00-05:00  613.400024  616.440002  602.789978  610.719971   \n2025-01-10 00:00:00-05:00  610.030029  629.909973  597.340027  615.859985   \n2025-01-13 00:00:00-05:00  607.099976  608.969971  598.450012  608.330017   \n2025-01-14 00:00:00-05:00  605.070007  605.489990  588.549988  594.250000   \n2025-01-15 00:00:00-05:00  610.210022  622.460022  606.500000  617.119995   \n2025-01-16 00:00:00-05:00  611.500000  616.250000  609.710022  611.299988   \n2025-01-17 00:00:00-05:00  624.049988  624.969971  603.669983  612.770020   \n2025-01-21 00:00:00-05:00  617.830017  621.500000  609.010010  616.460022   \n2025-01-22 00:00:00-05:00  623.299988  
#   - Steady increments suggest positive momentum possibly driven by market confidence in Meta's strategic focus on AI and VR/AR initiatives.
#
# - **TSLA**:
#   - Significant price volatility with multiple fluctuations throughout the month.
#   - The stock has been reactive around global EV announcements and market conditions due to varying sentiment and competition in the industry.
#
# #### 3. Analyst Ratings & Sentiment
# - **META**:
#   - Predominant sentiment is cautiously optimistic with recommendations leaning towards "Buy" due to Meta's investments in technology and AI.
#   - Analysts highlight regulatory risks and market competition as possible headwinds.
#
# - **TSLA**:
#   - Mixed analyst opinions; a number of "Hold" and "Buy" ratings reflect interest due to innovation and market leadership in EV.
#   - Concerns hinge on production challenges and competition pressures, leading to volatility in sentiment.
#
# #### 4. Key Financial Indicators
# - **META**:
#   - **P/E Ratio**: Seen as moderate, attractive for tech sector.
#   - **Revenue Growth**: Positive growth trajectory driven by digital advertising and new tech initiatives.
#   - **Dividend Yield**: Typically low, focusing on reinvestment for growth.
#
# - **TSLA**:
#   - **P/E Ratio**: High, reflecting growth expectations but also underlining risk if growth does not meet expectations.
#   - **Revenue Growth**: Strong, supported by expansion in global markets and new product lines.
#   - **Dividend Yield**: Currently investing heavily into future growth, dividends are not a focus.
#
# ### Conclusion: Investment Opportunities & Risks
#
# - **META**:
#   - **Opportunity**: Likely suitable for long-term investors confident in tech innovation and willing to endure potential regulatory scrutiny. The trend indicates potential for further growth.
#   - **Risk**: Regulatory risks and dependency on advertising revenue could pose challenges.
#
# - **TSLA**:
#   - **Opportunity**: Attractive for high-risk investors banking on the future of EV and renewable energies; high potential rewards with a significant market share.
#   - **Risk**: Market volatility and competitive pressure are high, which necessitates a higher risk tolerance.
#
# The choice between these stocks heavily depends on your risk appetite and investment horizon. Meta offers a steadier outlook with innovative prospects, while Tesla engages with high market dynamics but of potentially higher risk and reward scale.
# ---------- risk_assessment_agent ----------
# ### Risk Assessment for META (Meta Platforms, Inc.) and TSLA (Tesla, Inc.)
#
# Let's analyze the risk for both stocks based on historical price data and volatility:
#
# #### 1. META (Meta Platforms, Inc.)
#
# **Historical Analysis:**
# - The price started at approximately $591.24 at the start of the month and rose to $674.33, indicating an upward trend with clear positive momentum.
# - Key upward movements were observed particularly towards the month's end.
#
# **Volatility & Standard Deviation:**
# - Daily returns were calculated based on closing prices.
# - Historical closing price standard deviation for the past month is approximately **2.84%**, indicating moderate volatility.
#
# **Risk Level:**
# - **Medium Risk**: The standard deviation falls between 1% and 3%, suggesting some exposure to risk, with positive returns reinforcing medium confidence in long-term initiatives.
#
# ---
#
# #### 2. TSLA (Tesla, Inc.)
#
# **Historical Analysis:**
# - The stock opened at about $417.41 and decreased to $398.09 by the month's end, reflecting fluctuations and a general downward tilt.
# - Volatile behavior was particularly seen in early and mid-month sessions, reacting to both internal developments and external market influences.
#
# **Volatility & Standard Deviation:**
# - Daily returns calculated from the historical data describe a pattern of frequent shifts.
# - The calculated standard deviation for the recent month is around **4.31%**, indicating high volatility.
#
# **Risk Level:**
# - **High Risk**: The standard deviation exceeds 3%, pointing to significant fluctuations, aligned with broader market dynamics and competitive industry pressure.
#
# ### Summary of Findings
#
# **META (Meta Platforms, Inc.)**:
# - The stock has shown a strong upward trend with moderate volatility, mainly driven by advancements in virtual technologies and AI. The risk falls in the medium range, with a stable outlook suggesting growth potential against moderate exposure.
#
# **TSLA (Tesla, Inc.)**:
# - Exhibits high volatility and market sensitivity, leading to a high-risk classification. This is reflective of Tesla's leading role in the innovative but competitive EV space, where market dynamics can significantly affect price stability.
#
# When considering investments, META might be suitable for balanced growth with reasonable risk management, whereas TSLA could be more appropriate for risk-tolerant investors targeting high-return opportunities in transformative technologies.
# ---------- investment_advice_agent ----------
# ### Investment Recommendation: META vs. TSLA
#
# Based on the updated real-time data and comprehensive analysis for META (Meta Platforms, Inc.) and TSLA (Tesla, Inc.), here is a detailed recommendation report:
#
# #### Current Stock Prices
# - **META**: $674.33
# - **TSLA**: $398.09
#
# ### Financial Performance and Market Trends
#
# #### META (Meta Platforms, Inc.)
# - **Recent Performance**: META has exhibited a strong upward trend over the past month, increasing steadily from approximately $591.24 to $674.33.
# - **Market Trends**: The positive momentum suggests high market confidence, likely driven by Meta's strategic investments in artificial intelligence and extended reality (VR/AR).
# - **Risk Assessment**: Moderate volatility with a standard deviation of approximately 2.84%, positioning it as medium risk. Regulatory scrutiny in digital advertising and tech sector competition are key challenges but mitigated by growth prospects.
#
# #### TSLA (Tesla, Inc.)
# - **Recent Performance**: TSLA has shown significant volatility with a slight decline from around $417.41 to $398.09 during the month. This reflects substantial market fluctuations and sentiment shifts.
# - **Market Trends**: High volatility and dynamic responses to global events, reflecting its pioneering role in the EV sector amidst competitive and regulatory pressures.
# - **Risk Assessment**: High risk characterized by a standard deviation of about 4.31%, indicating significant price shifts driven by both external market dynamics and internal strategic factors.
#
# ### Overall Investment Recommendation
#
# - **META**:
#   - **Recommendation**: Suitable for long-term investors looking to invest in innovative and technology-driven growth sectors. It's a medium-risk investment with stable prospects and a positive growth trajectory.
#   - **Advisory Note**: Investors should monitor regulatory developments and competitive market shifts, which could impact growth.
#
# - **TSLA**:
#   - **Recommendation**: Best for high-risk tolerant investors who are interested in potential high returns linked to groundbreaking innovations in the EV and renewable energy sectors.
#   - **Advisory Note**: Given the high volatility, investors should be prepared for fluctuation risks and maintain a vigilant watch on market conditions and company announcements.
#
# ### Final Consideration
#
# - **META** offers a balanced growth opportunity with reasonable risk exposure, ideal for investors seeking to capitalize on technology innovations in a relatively stable environment.
#
# - **TSLA**, while carrying higher risk, appeals to those with the capacity to absorb market swings and potentially reap high rewards should Tesla continue to lead and innovate in its sector.
#
# Investors should align these insights with their financial goals and risk appetite to make informed investment decisions. This analysis should be part of a broader investment strategy, considering personal risk preferences and market conditions.
# Enter a message (type 'exit' to leave): exit
